# %% [markdown]
# # Estimation of Prediction for getting heart disease using Logistic Regression Model of Machine Learning

# %% [markdown]
# # 1. Import Modules for Data Analysis

# %%
# import common modules for data analysis
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %%
# install the pyreadstat module
# !pip install pyreadstat

# %% [markdown]
# # 1. Data Acquisition

# %%
df_heart=pd.read_csv("Heart_Disease_Prediction.csv")
df_heart
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %% [markdown]
# # 1.1 Scanning the dataframe

# %%
df_heart.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
## dimensions
df_heart.shape
# Out:
# (270, 14)

# %%
# what are the datatypes of the columns
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# ...

# %%
## basic descriptive
pd.set_option('display.float_format', lambda x: '% .3f' % x)
df_heart.describe().transpose()
# Out:
#                            count     mean     std      min      25%      50%  \
# Age                      270.000   54.433   9.109   29.000   48.000   55.000
# Sex                      270.000    0.678   0.468    0.000    0.000    1.000
# Chest pain type          270.000    3.174   0.950    1.000    3.000    3.000
# BP                       270.000  131.344  17.862   94.000  120.000  130.000
# Cholesterol              270.000  249.659  51.686  126.000  213.000  245.000
# FBS over 120             270.000    0.148   0.356    0.000    0.000    0.000
# EKG results              270.000    1.022   0.998    0.000    0.000    2.000
# Max HR                   270.000  149.678  23.166   71.000  133.000  153.500
# Exercise angina          270.000    0.330   0.471    0.000    0.000    0.000
# ST depression            270.000    1.050   1.145    0.000    0.000    0.800
# Slope of ST              270.000    1.585   0.614    1.000    1.000    2.000
# ...

# %% [markdown]
# # 2.Plotting The Graphs

# %%
sns.countplot(x="Cholesterol",data=df_heart)
# Out:
# <Axes: xlabel='Cholesterol', ylabel='count'>

# %%
sns.countplot(x="ST depression", data=df_heart)
# Out:
# <Axes: xlabel='ST depression', ylabel='count'>

# %%
df_heart["Age"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_heart["Number of vessels fluro"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_heart["Thallium"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(x="Max HR",data=df_heart)
# Out:
# <Axes: xlabel='Max HR', ylabel='count'>

# %% [markdown]
# # 3.Finding The Null Values|

# %%
df_heart.isnull()
# Out:
#        Age    Sex  Chest pain type     BP  Cholesterol  FBS over 120  \
# 0    False  False            False  False        False         False
# 1    False  False            False  False        False         False
# 2    False  False            False  False        False         False
# 3    False  False            False  False        False         False
# 4    False  False            False  False        False         False
# ..     ...    ...              ...    ...          ...           ...
# 265  False  False            False  False        False         False
# 266  False  False            False  False        False         False
# 267  False  False            False  False        False         False
# 268  False  False            False  False        False         False
# 269  False  False            False  False        False         False
#
#      EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
df_heart.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %% [markdown]
# # 4.Plot The Heatmap

# %%
sns.heatmap(df_heart.isnull(), yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# # 5.Droping the values

# %%
df_heart.drop("BP", axis=1, inplace=True)
df_heart.head()
# Out:
#    Age  Chest pain type  Cholesterol  FBS over 120  EKG results  Max HR  \
# 0   70                4          322             0            2     109
# 1   67                3          564             0            2     160
# 2   57                2          261             0            0     141
# 3   64                4          263             0            0     105
# 4   74                2          269             0            2     121
#
#    Exercise angina  ST depression  Slope of ST  Number of vessels fluro  \
# 0                0          2.400            2                        3
# 1                0          1.600            2                        0
# 2                0          0.300            1                        0
# 3                1          0.200            2                        1
# 4                1          0.200            1                        1
#
#    Thallium Heart Disease
# 0         3      Presence
# 1         7       Absence
# ...

# %%
m=np.mean(df_heart["Cholesterol"])
print(m)
# Out:
# 249.65925925925927

# %% [markdown]
# # 6.Replacing the Null values

# %%
df_heart["Cholesterol"].replace(to_replace= np.nan, value=m, inplace=True )
df_heart["FBS over 120"].replace(to_replace = np.nan, value =25, inplace=True)
df_heart["EKG results"].replace(to_replace= np.nan , value =5, inplace=True)
df_heart["Heart Disease"].replace(to_replace = np.nan , value= 90, inplace=True)
df_heart.drop("Exercise angina", axis=1,inplace=True)

# %%
df_heart["Cholesterol"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_heart.head(10)
# Out:
#    Age  Chest pain type  Cholesterol  FBS over 120  EKG results  Max HR  \
# 0   70                4          322             0            2     109
# 1   67                3          564             0            2     160
# 2   57                2          261             0            0     141
# 3   64                4          263             0            0     105
# 4   74                2          269             0            2     121
# 5   65                4          177             0            0     140
# 6   56                3          256             1            2     142
# 7   59                4          239             0            2     142
# 8   60                4          293             0            2     170
# 9   63                4          407             0            2     154
#
#    ST depression  Slope of ST  Number of vessels fluro  Thallium Heart Disease
# 0          2.400            2                        3         3      Presence
# ...

# %%
sns.heatmap(df_heart.isnull(), yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
df_heart["Chest pain type"].replace(to_replace=np.nan, value=247.0, inplace=True)
df_heart.drop("Max HR",axis=1,inplace=True)

# %%
sns.heatmap(df_heart.isnull(), yticklabels=False, cmap="viridis")
# Out:
# <Axes: >

# %%
df_heart.isnull().sum()
# Out:
# Age                        0
# Chest pain type            0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
sns.countplot(x="Heart Disease" , data=df_heart)
# Out:
# <Axes: xlabel='Heart Disease', ylabel='count'>

# %%
x=df_heart.drop("Heart Disease",axis=1)
y=df_heart["Heart Disease"].values
y
# Out:
# array(['Presence', 'Absence', 'Presence', 'Absence', 'Absence', 'Absence',
#        'Presence', 'Presence', 'Presence', 'Presence', 'Absence',
#        'Absence', 'Absence', 'Presence', 'Absence', 'Absence', 'Presence',
#        'Presence', 'Absence', 'Absence', 'Presence', 'Absence', 'Absence',
#        'Absence', 'Absence', 'Absence', 'Absence', 'Absence', 'Presence',
#        'Absence', 'Presence', 'Absence', 'Absence', 'Presence',
#        'Presence', 'Presence', 'Presence', 'Presence', 'Absence',
#        'Absence', 'Presence', 'Absence', 'Absence', 'Absence', 'Presence',
#        'Absence', 'Presence', 'Presence', 'Presence', 'Presence',
#        'Presence', 'Absence', 'Absence', 'Absence', 'Absence', 'Absence',
#        'Presence', 'Absence', 'Presence', 'Presence', 'Absence',
#        'Presence', 'Absence', 'Absence', 'Absence', 'Presence', 'Absence',
#        'Presence', 'Absence', 'Presence', 'Presence', 'Absence',
# ...

# %% [markdown]
# # 7. Train and Test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.2,random_state=15)
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression().fit(x_train,y_train)
y_pred = clf.predict(x_test)
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
accuracy
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

#Normalize the data attributes for the Iris dataset.
from sklearn.datasets import load_iris
from sklearn import preprocessing
# load the iris dataset
iris = load_iris()
print(iris.data.shape)
# separate the data from the target attributes
x = iris.data
y = iris.target
# normalize the data attributes
normalized_x = preprocessing.normalize(x)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# (150, 4)

# %%
print('Accuracy Score : ' + str(accuracy_score(y_test, y_pred)))
print('Precision Score : ' + str(precision_score(y_test, y_pred, pos_label='Presence')))
print('Recall Score : ' + str(recall_score(y_test, y_pred, pos_label='Presence')))
print('F1 Score : ' + str(f1_score(y_test, y_pred, pos_label='Presence')))
from sklearn.metrics import confusion_matrix
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_pred)))
# Out:
# Accuracy Score : 0.7222222222222222
# Precision Score : 0.8095238095238095
# Recall Score : 0.6071428571428571
# F1 Score : 0.6938775510204083
# Confusion Matrix :
# [[22  4]
#  [11 17]]

# %%
from sklearn.model_selection import GridSearchCV
# Define the model
clf = LogisticRegression()

# Define the parameter grid
grid_values = {'penalty': ['l1', 'l2'], 'C': [0.001, 0.009, 0.01, 0.09, 1, 5, 10, 25, 15, 100]}

# Perform grid search with cross-validation
grid_clf_acc = GridSearchCV(clf, param_grid=grid_values, scoring='accuracy')

# Fit the model
grid_clf_acc.fit(x_train, y_train)

# Predict values based on the best found parameters
y_pred = grid_clf_acc.predict(x_test)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # 8.Accuracy Score

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.7222222222222222
